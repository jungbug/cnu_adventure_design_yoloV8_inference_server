# %%
results = model.train(data="./data.yaml", epochs=100, imgsz=640, project="food", name="yolov8n")
# Out:
# Ultralytics YOLOv8.0.203  Python-3.8.18 torch-2.1.0+cpu CPU (13th Gen Intel Core(TM) i7-13700KF)
# ...
