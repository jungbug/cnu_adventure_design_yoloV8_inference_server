# %%
from ultralytics import YOLO
from PIL import Image
import matplotlib.pyplot as plt

# %%
model = YOLO("./food/yolov8n/weights/best.pt")

# %%
source = "./test.jpg"
image = Image.open(source)

# %%
results = model(source)
# Out:
# image 1/1 /Volumes/무제/university/어밴디/project-inference/test.jpg: 640x640 1 apple, 1 blueberries, 1 cheese, 1 chicken, 1 chocolate, 1 eggs, 1 onion, 1 potato, 1 spinach, 2 tomatos, 250.7ms
# Speed: 5.9ms preprocess, 250.7ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)

# %%
for r in results:
    im_array = r.plot()  # plot a BGR numpy array of predictions
    im = Image.fromarray(im_array[..., ::-1])  # RGB PIL image
    plt.imshow(im)

# %%
for result in results:
    boxes = result.boxes  # Boxes object for bbox outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    probs = result.probs

box = result[0].boxes
for box in result.boxes:
  class_id = result.names[box.cls[0].item()]
  cords = box.xyxy[0].tolist()
  cords = [round(x) for x in cords]
  conf = round(box.conf[0].item(), 2)
  print("Object type:", class_id)
# Out:
# Object type: spinach
# Object type: apple
# Object type: onion
# Object type: chicken
# Object type: blueberries
# Object type: tomato
# Object type: chocolate
# Object type: potato
# Object type: cheese
# Object type: eggs
# Object type: tomato
