# %%
from ultralytics import YOLO
from PIL import Image
import matplotlib.pyplot as plt

# %%
model = YOLO("./food/yolov8n/weights/best.pt")

# %%
source = "./냉장고3.jpg"
image = Image.open(source)

# %%
results = model(source)
# Out:
# image 1/1 c:\Users\xbox1\Desktop\yolo\cnu_adventure_design_yoloV8_inference_server\3.jpg: 384x640 1 apple, 2 milks, 42.3ms
# Speed: 1.0ms preprocess, 42.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)

# %%
for r in results:
    im_array = r.plot()  # plot a BGR numpy array of predictions
    im = Image.fromarray(im_array[..., ::-1])  # RGB PIL image
    plt.imshow(im)
